# %% [markdown]
# <center>
#   <a href="MLIP-04-pandas.ipynb" target="_self">The pandas Library</a> | <a href="./">Content Page</a> | <a href="MLIP-06-Classification.ipynb">Classification | <a href="MLIP-05-RegressionAnalysis-Exercises.ipynb">Regression Analysis Exercises</a>
# </center>

# %% [markdown]
# # <center>MODEL BUILDING AND EVALUATION</center>
#
# <center><b>Copyright &copy 2023 by DR DANNY POO</b><br> e:dannypoo@nus.edu.sg<br> w:drdannypoo.com</center><br>

# %% [markdown]
# # Tasks
# - To read in and explore data set.
# - To <b>handle missing value</b>.
# - To <b>understand distribution of data</b>.
# - To <b>detect outliers</b>.
# - To <b>understand correlation in data</b>.
# - To <b>fit a model</b>.
# - To <b>evaluate model performance</b>.

# %% [markdown]
# ## Read in and Explore Data Set

# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in data
df = pd.read_csv('./data/salary/salaryWithMissingData.csv')
df[0:10]
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3      NaN
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2      NaN
# 5              2.9  56642.0
# 6              NaN  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
# Display NaN values using heatmap
sns.heatmap(df.isnull(),cmap="Blues")
plt.show()

# %% [markdown]
# ## Missing Value Handling

# %%
# Replace Missing Values in YearsExperience with the Mean Value
# write code here
df["YearsExperience"].fillna(df["YearsExperience"].mean())
# Out:
# 0      1.100000
# 1      1.300000
# 2      1.500000
# 3      2.000000
# 4      2.200000
# 5      2.900000
# 6      5.322222
# 7      3.200000
# 8      3.200000
# 9      3.700000
# 10     3.900000
# 11     4.000000
# 12     5.322222
# 13     4.100000
# 14     4.500000
# 15     4.900000
# 16     5.100000
# 17     5.300000
# 18     5.900000
# 19     6.000000
# 20     6.800000
# 21     7.100000
# 22     7.900000
# 23     8.200000
# 24     5.322222
# 25     9.000000
# 26     9.500000
# 27     9.600000
# 28    10.300000
# 29    10.500000
# Name: YearsExperience, dtype: float64

# %%
# Replace Missing Values in Salary with the Mean Value
# write code here
df["Salary"].fillna(df["Salary"].mean())
# Out:
# 0      39343.000000
# 1      77272.576923
# 2      37731.000000
# 3      43525.000000
# 4      77272.576923
# 5      56642.000000
# 6      60150.000000
# 7      54445.000000
# 8      64445.000000
# 9      57189.000000
# 10     63218.000000
# 11     55794.000000
# 12     56957.000000
# 13     57081.000000
# 14     61111.000000
# 15     77272.576923
# 16     66029.000000
# 17     83088.000000
# 18     81363.000000
# 19     93940.000000
# 20     91738.000000
# 21     98273.000000
# 22    101302.000000
# 23    113812.000000
# 24    109431.000000
# 25    105582.000000
# 26     77272.576923
# 27    112635.000000
# 28    122391.000000
# 29    121872.000000
# Name: Salary, dtype: float64

# %%
# Replace Missing Values in YearsExperience with the Median Value
# write code here
df["YearsExperience"].fillna(df["YearsExperience"].median())
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      4.9
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.9
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     4.9
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
# Replace Missing Values in Salary with the Median Value
# write code here
df["Salary"].fillna(df["Salary"].median())
# Out:
# 0      39343.0
# 1      65237.0
# 2      37731.0
# 3      43525.0
# 4      65237.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     65237.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26     65237.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Understanding Distribution of Data

# %%
# Plot distribution of Experience
sns.distplot(df["YearsExperience"])
plt.ylabel("Frequency")
plt.xlabel("Experience")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Observations**
# - The histogram shows that the values of employees’ years of work experience slightly follow a normal distribution.

# %%
# Plot distribution of Salary
sns.distplot(df["Salary"])
plt.ylabel("Frequency")
plt.xlabel("Salary")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Observations**
# - The histogram shows that the values of employees’ salary slightly follow a normal distribution.
# - Both histograms show non-extreme normal distributions.

# %% [markdown]
# ## Outlier Detection

# %%
# Plot Employees' Years of Work Experience box plot
sns.boxplot(df["YearsExperience"])
plt.xlabel("Experience")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations**
# - The box plot shows the values of employees’ years of work experience are slightly skewed to the left, and there were no outliers in the data.

# %%
# Plot Employees' Years of Work Experience box plot
sns.boxplot(df["Salary"])
plt.xlabel("Salary")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations**
# - The box plot shows the values of employees’ salaries are skewed to the left, and there are no outliers detected in the data.
# - Both box plots indicates the values of employees' salaries are skewed to the left and there are no outliers detected in the data.
# - Both box plots slightly resemble a normal distribution.

# %% [markdown]
# ## Understanding Correlation in Data

# %%
# Read in data
df = pd.read_csv('./data/salary/salary.csv')
df[0:10]
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
# Plot Employees' Years of Work Experience and Employees' Salaries line plot
df.plot(kind="line")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# **Observations**
# - The straight line slopes upward and to the right.
# - Employees’ salaries increase as their years of work experience increase.

# %%
# Plot Employees' Years of Work Experience and Employees' Salaries joint plot
sns.jointplot(x="YearsExperience",y="Salary",data=df,kind="reg")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# **Observations**
# - The plot indicates that a straight line perfectly fits the data points.
# - There is a strong positive correlation relationship between employees’ years of work experience and employees’ salaries.

# %%
# Plot Correlation Matrix heatmap
dfcorr = df.corr(method="pearson")
sns.heatmap(dfcorr, annot=True,annot_kws={"size":12}, cmap="Blues")
plt.show()

# %% [markdown]
# **Observations**
# - The heatmap indicates there is strong positive correlation between the employees’ years of work experience and the employees’ salaries.

# %%
# Summarize the Central Tendency
df.describe().transpose()
# Out:
#                  count          mean           std      min       25%  \
# YearsExperience   30.0      5.313333      2.837888      1.1      3.20
# Salary            30.0  76003.000000  27414.429785  37731.0  56720.75
#
#                      50%        75%       max
# YearsExperience      4.7       7.70      10.5
# Salary           65237.0  100544.75  122391.0

# %% [markdown]
# **Observations**
# - The arithmetic average of employees’ work experience is 5 years and that of employees’ salaries is 76,003 dollars per year.
# - The values of employees’ years of work experience deviate away from the mean value by 3, and the values of employees’ salaries deviate by 27,414 dollars.
# - The lowest number of work year experience is 1 year, and the lowest salary is 37,731 dollars.
# - An employee with the highest salary earns 122,391 dollars annually and has about 11 years of work experience.
# - One out of four employees earns a salary of about 56,721 dollars annually.
# - Employees who earn a salary of 100,544 dollars and above annually fall under the upper echelon.

# %% [markdown]
# ## Fitting a Model

# %%
# Assigns arrays of X and y using Numpy
X = np.array(df["YearsExperience"])
y = np.array(df["Salary"])

# %%
X.shape
# Out:
# (30,)

# %%
y.shape
# Out:
# (30,)

# %%
# Reshape X and y arrays into 1 dimensional arrays
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
X.shape
# Out:
# (30, 1)

# %%
y.shape
# Out:
# (30, 1)

# %% [markdown]
# ### Split Data

# %%
# Split data into Training and Test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Normalize Data

# %%
# Normalize data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Add a constant because statsmodel does not have an intercept
import statsmodels.api as sm
X_constant = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %% [markdown]
# ### Train Model

# %%
# Develop the Least Squares Model
model = sm.OLS(y_train, X_constant).fit()

# %% [markdown]
# ### Predict on Test Data

# %%
# Predict
y_pred = model.predict(X_test)
pd.DataFrame(y_pred, columns = ["Predicted salary"])
# Out:
#    Predicted salary
# 0      40748.961841
# 1     122699.622956
# 2      64961.657170
# 3      63099.142145
# 4     115249.562855
# 5     107799.502753

# %% [markdown]
# ## Evaluate Model Performance

# %%
# Profile results
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     352.1
# Date:                Mon, 20 Feb 2023   Prob (F-statistic):           5.03e-15
# Time:                        16:23:44   Log-Likelihood:                -242.89
# No. Observations:                  24   AIC:                             489.8
# Df Residuals:                      22   BIC:                             492.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.389e+04   1281.861     57.640      0.000    7.12e+04    7.65e+04
# ...

# %% [markdown]
# **Observations**
# - R-squared represents the variation the model explains about the data.
# - Adjusted R-squared represents the variation of the independent variable that influences the dependent variable explains.
# - The model explains 94.1% of the variation in the data, and the independent variable (YearsExperience) explains 93.9% of the variation in the data.
# - The model best explains the data.
# - The p-value was barely 0.05 (at 0.000). We reject the null hypothesis in favor of the alternative hypothesis. That is, there is a significant difference between the employees’ years of work experience and the employees’ salaries.
# - Kurtosis:<br>
# Coefficient value = 3 -> perfectly fits a normal curve<br>
# Coefficient value < 3 -> hyponormal (i.e. assigns lower frequencies to the values close to the mean)<br>
# Coefficient value > 3 -> hypernormal (i.e. assigns higher frequencies to the values close to the mean)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <center>
#   <a href="MLIP-04-pandas.ipynb" target="_self">The pandas Library</a> | <a href="./">Content Page</a> | <a href="MLIP-06-Classification.ipynb">Classification | <a href="MLIP-05-RegressionAnalysis-Exercises.ipynb">Regression Analysis Exercises</a>
# </center>
